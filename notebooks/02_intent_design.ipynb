# %%
# Sample 50 customer messages to inspect real complaints
random.seed(42)
sample = random.sample(train_data, 50)

for i, ex in enumerate(sample[:30]):
    print(f"--- Example {i+1} ---")
    print(f"Customer: {ex['customer_message']}")
    print(f"Brand:    {ex['brand_reply'][:100]}...\n")
# Out:
# --- Example 1 ---
# Customer: the glitch problem happens with the letters O, U, and K too 🤔 [URL]
# Brand:    We'd like to help out. DM us and we'll go from there. [URL]...
#
# --- Example 2 ---
# Customer: I don’t know what it is, but I got the feeling that my iPhone 6 battery is running out much faster than before. Can it be the new software update or another reason?
# Brand:    we want to help. Which version of iOS 11 is running on your device?...
#
# --- Example 3 ---
# Customer: And now Apple isn't helping either
# Brand:    Thanks for the additional details. This article may help with this issue: [URL]...
#
# --- Example 4 ---
# Customer: Yes I’m using the latest 11.0.2!
# Brand:    We'd like to look into this with you more. Please send us a DM and we'll continue. [URL]...
#
# --- Example 5 ---
# Customer: Too many things wrong to list on Twitter
# Brand:    Hi there, we'd like to help. Please DM us and we'll go from there. [URL]...
#
# --- Example 6 ---
# ...

# %%
import json
import random

with open('../data/processed/AppleSupport/train.json', 'r', encoding='utf-8') as f:
    train_data = json.load(f)

print(f"Total training examples: {len(train_data):,}")
# Out:
# Total training examples: 5,063
